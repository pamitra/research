# %% [markdown]
# <a href="https://colab.research.google.com/github/pamitra/research/blob/QRGenerator_Draft/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Hello World in Python!**

# %%
print("Hello World how are you?")
# This a is a comment
# Out:
# Hello World how are you?

# %% [markdown]
# # **Datatype**

# %%
a = 12
print(a)
print(type(a))
# Out:
# 12
# <class 'int'>

# %%
b = 1.7
print(b)
print(type(b))
# Out:
# 1.7
# <class 'float'>

# %%
c = "Python"
print(c)
print(type(c))
# Out:
# Python
# <class 'str'>

# %%
d = True
print(d)
print(type(d))
# Out:
# True
# <class 'bool'>

# %%
a, b, c = 1, 2, 3
a, b, c = 1, 3.5, "hello"
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# # **Math Operation**

# %%
a = 77
b = a * 0.22
b = b + 2000
print (b)
# Out:
# 2016.94

# %%
c = int(b)
print (c)
# Out:
# 16

# %%
c = int(round(b,0))
print (c)
# Out:
# 17

# %%
a = 77
b = a * 0.22
print (b)

# %% [markdown]
# # Boolean

# %%
x = True
y = False
print(x and y)
print(x or y)
print(not x)
print(x & y)
# Out:
# False
# True
# False
# False

# %% [markdown]
# # Printing

# %%
message = "Lets Learn AI"

# %%
print (message)

# %%
print ("The Message is - ",message )

# %%
print (message,".",sep="Come on", end="Team")

# %%
print ("a =","5",sep="00",end=".000")

# %%
first = "Artificial"
last = "Intelligence"

print("You Know? {} {}, is the new trend!".format(first,last))

# %%
print("%s%s" % (first, last))

# %%
float = 2.154327
print( "{:.2f}".format(float))

# %%
print ("%.2f" % (float))
